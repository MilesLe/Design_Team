# %% [markdown]
# https://github.com/MilesLe/Design_Team

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from os import listdir
from os.path import isfile, join

# %% [markdown]
# Extract Data
# - Add new data files here to be processed in the pipeline.
#
# Filename
# - Trial number
# - User
# - date: day, month, year
# - Setup env
# - Type of material (ex. Suture pad, Diaphragm)
# - ex. 1_kathy_09102022_AnchorFailureBlackAcryllic_SuturePad.log

# %%
file_path = "./data/Suture_Pullout_Force_Measurements_(Suture Pad_Acrylic_w_circle)/"
data_files = [f for f in listdir(mypath) if isfile(join(mypath, f))]
print(data_files)
# Out:
# ['15_emma_13112022_AnchorFailureBlackAcrylic_SuturePad.log', '18_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log', '15_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log', '21_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log', '4_emma_03112022_AnchorFailureBlackAcrylic_SuturePad.log', '8_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log', '1_kathy_03112022_AnchorFailureBlackAcrylic_SuturePad.log', '27_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log', '13_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log', '19_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log', '9_emma_13112022_AnchorFailureBlackAcrylic_SuturePad.log', '11_emma_13112022_AnchorFailureBlackAcrylic_SuturePad.log', '14_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log', '32_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log', '13_emma_13112022_AnchorFailureBlackAcrylic_SuturePad.log', '9_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log', '20_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log', '26_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log', '7_emma_10112022_AnchorFailureBlackAcrylic_SuturePad.log', '12_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log', '2_emma_03112022_AnchorFailureBlackAcrylic_SuturePad.log', '5_kathy_03112022_AnchorFailureBlackAcrylic_SuturePad.log', '8_emma_13112022_AnchorFailureBlackAcrylic_SuturePad.log', '10_emma_13112022_AnchorFailureBlackAcrylic_SuturePad.log', '23_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log', '31_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log', '1_emma_03112022_AnchorFailureBlackAcrylic_SuturePad.log', '17_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log', '28_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log', '12_emma_13112022_AnchorFailureBlackAcrylic_SuturePad.log', '3_kathy_03112022_AnchorFailureBlackAcrylic_SuturePad.log', '11_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log', '3_emma_03112022_AnchorFailureBlackAcrylic_SuturePad.log', '25_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log', '6_emma_10112022_AnchorFailureBlackAcrylic_SuturePad.log', '7_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log', '4_kathy_03112022_AnchorFailureBlackAcrylic_SuturePad.log', '14_emma_13112022_AnchorFailureBlackAcrylic_SuturePad.log', '5_emma_03112022_AnchorFailureBlackAcrylic_SuturePad.log', '22_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log', '30_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log', '16_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log', '29_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log', '2_kathy_03112022_AnchorFailureBlackAcrylic_SuturePad.log', '10_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log', '6_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log', '24_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log']

# %%
# Data extraction functions
''' 
Purpose: Extract all the data from the data files and organize them and meta data in a data structure.
Input: the data files with their category.
Return: main data structure.
'''
def extract_from_files(data_files):
    data = {}
    # iterate through each file provided
    for f in data_files:
        filename = f
        # meta data
        parsed_filename = f.split('_')
        trial= parsed_filename[0]
        user = parsed_filename[1]
        date = datetime.strptime(parsed_filename[2][:8], "%d%m%Y")
        setup_env = parsed_filename[3]
        material = parsed_filename[4][:-4]
        # raw data
        file_data = []
        for file in data_files:
            d = open(file_path + f, "r").read()
            d_arr = d.split("\n")
            d_arr_ = d_arr[6:len(d_arr)-1]
            for instance in d_arr_:
                instance_arr = instance.split("\t")
                file_data.append(instance_arr)
        raw_df = pd.DataFrame(file_data, columns =["Reading", "Load", "Travel", "Time" ]).drop(["Reading", "Travel"], axis=1)
        # add to main data struct.
        data[f] = {"trail": trial,
                   "user": user,
                   "date": date,
                   "setup_env": setup_env,
                   "material": material,
                   "data": raw_df}
            
    return data

# %%
# Raw data extraction from raw file. Apply data extraction functions
all_data = extract_from_files(data_files)
print(all_data)
# Out:
# {'15_emma_13112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '15', 'user': 'emma', 'date': datetime.datetime(2022, 11, 13, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -0.34  0.000
# 1     -0.34  0.048
# 2      0.34  0.214
# 3      0.34  0.248
# 4      0.34  0.298
# ...     ...    ...
# 6199   0.00  6.448
# 6200   0.00  6.498
# 6201   0.00  6.548
# 6202   0.00  6.598
# 6203   0.00  6.648
#
# [6204 rows x 2 columns]}, '18_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '18', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 6, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -1.98  0.000
# 1     -1.96  0.051
# 2     -1.98  0.099
# 3     -0.70  0.292
# 4     -0.70  0.299
# ...     ...    ...
# 6951   0.02  7.249
# 6952   0.02  7.298
# 6953   0.00  7.348
# 6954   0.02  7.398
# 6955   0.02  7.449
#
# [6956 rows x 2 columns]}, '15_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '15', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 6, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':       Load   Time
# 0     0.30  0.000
# 1     0.30  0.049
# 2     0.46  0.226
# 3     0.46  0.249
# 4     0.46  0.300
# ...    ...    ...
# 7891  0.02  8.249
# 7892  0.00  8.300
# 7893  0.02  8.349
# 7894  0.00  8.399
# 7895  0.02  8.449
#
# [7896 rows x 2 columns]}, '21_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '21', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 10, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -0.82  0.000
# 1     -0.70  0.190
# 2     -0.70  0.200
# 3     -0.80  0.251
# 4     -0.80  0.300
# ...     ...    ...
# 6669   0.00  6.951
# 6670   0.00  7.000
# 6671   0.00  7.051
# 6672   0.00  7.100
# 6673   0.00  7.150
#
# [6674 rows x 2 columns]}, '4_emma_03112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '4', 'user': 'emma', 'date': datetime.datetime(2022, 11, 3, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -3.22  0.000
# 1     -3.22  0.049
# 2     -3.22  0.099
# 3     -2.12  0.261
# 4     -2.12  0.299
# ...     ...    ...
# 6481   0.00  6.749
# 6482   0.00  6.800
# 6483   0.00  6.849
# 6484   0.00  6.899
# 6485   0.00  6.949
#
# [6486 rows x 2 columns]}, '8_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '8', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 6, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -1.94  0.000
# 1     -1.94  0.048
# 2     -1.94  0.098
# 3     -0.40  0.262
# 4     -0.40  0.297
# ...     ...    ...
# 7374   0.00  7.697
# 7375   0.00  7.747
# 7376   0.00  7.797
# 7377   0.00  7.847
# 7378   0.00  7.897
#
# [7379 rows x 2 columns]}, '1_kathy_03112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '1', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 3, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load    Time
# 0      0.42   0.000
# 1      0.64   0.191
# 2      0.64   0.199
# 3      0.64   0.250
# 4      0.42   0.299
# ...     ...     ...
# 10147  0.00  10.649
# 10148  0.00  10.700
# 10149  0.00  10.750
# 10150  0.00  10.799
# 10151  0.00  10.850
#
# [10152 rows x 2 columns]}, '27_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '27', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 10, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -1.40  0.000
# 1     -1.40  0.051
# 2     -1.34  0.245
# 3     -1.34  0.250
# 4     -1.34  0.300
# ...     ...    ...
# 6434   0.00  6.700
# 6435   0.02  6.751
# 6436   0.02  6.800
# 6437   0.00  6.850
# 6438   0.02  6.900
#
# [6439 rows x 2 columns]}, '13_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '13', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 6, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -2.24  0.000
# 1     -2.24  0.051
# 2     -0.94  0.241
# 3     -0.94  0.250
# 4     -0.94  0.300
# ...     ...    ...
# 8032   0.00  8.400
# 8033   0.00  8.451
# 8034   0.00  8.500
# 8035   0.00  8.551
# 8036   0.00  8.601
#
# [8037 rows x 2 columns]}, '19_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '19', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 6, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -1.46  0.000
# 1     -1.46  0.049
# 2     -0.36  0.218
# 3     -0.36  0.249
# 4     -0.36  0.300
# ...     ...    ...
# 7891   0.02  8.249
# 7892   0.02  8.299
# 7893   0.02  8.349
# 7894   0.02  8.399
# 7895   0.00  8.449
#
# [7896 rows x 2 columns]}, '9_emma_13112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '9', 'user': 'emma', 'date': datetime.datetime(2022, 11, 13, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load    Time
# 0      0.36   0.000
# 1      0.36   0.050
# 2      0.32   0.236
# 3      0.32   0.249
# 4      0.32   0.300
# ...     ...     ...
# 13296  0.00  14.099
# 13297  0.00  14.151
# 13298  0.00  14.199
# 13299  0.00  14.250
# 13300  0.00  14.299
#
# [13301 rows x 2 columns]}, '11_emma_13112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '11', 'user': 'emma', 'date': datetime.datetime(2022, 11, 13, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -2.18  0.000
# 1      0.50  1.099
# 2      0.60  1.149
# 3      0.78  1.199
# 4      0.86  1.249
# ...     ...    ...
# 7374   0.00  8.650
# 7375   0.00  8.699
# 7376   0.00  8.749
# 7377   0.00  8.799
# 7378   0.00  8.849
#
# [7379 rows x 2 columns]}, '14_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '14', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 6, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -1.22  0.000
# 1     -1.22  0.050
# 2     -1.22  0.094
# 3     -0.34  0.287
# 4     -0.34  0.295
# ...     ...    ...
# 8267   0.00  8.645
# 8268   0.00  8.694
# 8269   0.00  8.744
# 8270   0.02  8.794
# 8271   0.02  8.845
#
# [8272 rows x 2 columns]}, '32_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '32', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 10, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -1.78  0.000
# 1     -0.30  0.172
# 2     -0.30  0.199
# 3     -0.30  0.249
# 4     -1.76  0.299
# ...     ...    ...
# 7374   0.02  7.699
# 7375   0.02  7.749
# 7376   0.02  7.799
# 7377   0.02  7.849
# 7378   0.02  7.899
#
# [7379 rows x 2 columns]}, '13_emma_13112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '13', 'user': 'emma', 'date': datetime.datetime(2022, 11, 13, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -1.62  0.000
# 1      0.88  0.206
# 2      0.88  0.245
# 3      0.88  0.295
# 4     -1.54  0.345
# ...     ...    ...
# 7797   0.00  8.195
# 7798   0.00  8.245
# 7799   0.00  8.295
# 7800   0.00  8.346
# 7801   0.00  8.395
#
# [7802 rows x 2 columns]}, '9_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '9', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 6, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -0.94  0.000
# 1     -0.94  0.050
# 2     -0.32  0.244
# 3     -0.32  0.250
# 4     -0.32  0.301
# ...     ...    ...
# 8361   0.00  8.750
# 8362   0.00  8.800
# 8363   0.00  8.850
# 8364   0.00  8.900
# 8365   0.00  8.950
#
# [8366 rows x 2 columns]}, '20_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '20', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 6, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load    Time
# 0     -2.34   0.000
# 1     -2.34   0.050
# 2     -0.46   0.248
# 3     -0.46   0.300
# 4     -2.32   0.351
# ...     ...     ...
# 9771   0.00  10.300
# 9772   0.00  10.350
# 9773   0.00  10.401
# 9774   0.02  10.451
# 9775   0.02  10.501
#
# [9776 rows x 2 columns]}, '26_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '26', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 10, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -2.92  0.000
# 1     -2.92  0.049
# 2     -0.46  0.232
# 3     -0.46  0.249
# 4     -0.46  0.299
# ...     ...    ...
# 8079   0.02  8.449
# 8080   0.02  8.499
# 8081   0.00  8.549
# 8082   0.00  8.599
# 8083   0.00  8.650
#
# [8084 rows x 2 columns]}, '7_emma_10112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '7', 'user': 'emma', 'date': datetime.datetime(2022, 11, 10, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -1.40  0.000
# 1     -1.40  0.049
# 2     -0.32  0.248
# 3     -0.32  0.298
# 4     -1.34  0.349
# ...     ...    ...
# 6528   0.02  6.849
# 6529   0.02  6.898
# 6530   0.02  6.948
# 6531   0.02  6.999
# 6532   0.02  7.048
#
# [6533 rows x 2 columns]}, '12_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '12', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 6, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -4.72  0.000
# 1     -0.64  1.094
# 2     -0.50  1.144
# 3     -0.36  1.195
# 4     -0.20  1.245
# ...     ...    ...
# 7092   0.00  8.344
# 7093   0.00  8.394
# 7094   0.02  8.444
# 7095   0.00  8.494
# 7096   0.00  8.544
#
# [7097 rows x 2 columns]}, '2_emma_03112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '2', 'user': 'emma', 'date': datetime.datetime(2022, 11, 3, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load    Time
# 0     -0.82   0.000
# 1     -0.84   0.049
# 2      0.12   0.211
# 3      0.12   0.249
# 4      0.12   0.299
# ...     ...     ...
# 9912   0.00  10.399
# 9913   0.00  10.450
# 9914   0.00  10.499
# 9915   0.00  10.550
# 9916   0.00  10.601
#
# [9917 rows x 2 columns]}, '5_kathy_03112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '5', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 3, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':         Load    Time
# 0      -3.08   0.000
# 1      -2.46   0.205
# 2      -2.46   0.250
# 3      -3.06   0.299
# 4      -3.00   0.349
# ...      ...     ...
# 11604   0.00  12.249
# 11605   0.00  12.300
# 11606   0.00  12.349
# 11607   0.00  12.400
# 11608   0.00  12.449
#
# [11609 rows x 2 columns]}, '8_emma_13112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '8', 'user': 'emma', 'date': datetime.datetime(2022, 11, 13, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':         Load    Time
# 0      -1.12   0.000
# 1       0.54   0.221
# 2       0.54   0.245
# 3       0.54   0.294
# 4      -1.10   0.344
# ...      ...     ...
# 14894   0.00  15.744
# 14895   0.00  15.795
# 14896   0.00  15.844
# 14897   0.00  15.895
# 14898   0.00  15.944
#
# [14899 rows x 2 columns]}, '10_emma_13112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '10', 'user': 'emma', 'date': datetime.datetime(2022, 11, 13, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':         Load    Time
# 0      -2.22   0.000
# 1      -2.22   0.049
# 2      -0.38   0.246
# 3      -0.38   0.299
# 4      -2.20   0.349
# ...      ...     ...
# 11980   0.00  12.649
# 11981   0.00  12.699
# 11982   0.00  12.749
# 11983   0.00  12.800
# 11984   0.00  12.849
#
# [11985 rows x 2 columns]}, '23_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '23', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 10, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -1.64  0.000
# 1     -0.42  0.201
# 2     -0.42  0.250
# 3     -1.62  0.300
# 4     -1.56  0.350
# ...     ...    ...
# 7045   0.02  7.400
# 7046   0.02  7.450
# 7047   0.02  7.500
# 7048   0.02  7.551
# 7049   0.02  7.600
#
# [7050 rows x 2 columns]}, '31_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '31', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 10, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':         Load    Time
# 0      -4.72   0.000
# 1      -2.78   0.210
# 2      -2.78   0.250
# 3      -2.78   0.300
# 4      -4.58   0.350
# ...      ...     ...
# 12450   0.02  13.151
# 12451   0.00  13.201
# 12452   0.02  13.250
# 12453   0.02  13.301
# 12454   0.02  13.350
#
# [12455 rows x 2 columns]}, '1_emma_03112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '1', 'user': 'emma', 'date': datetime.datetime(2022, 11, 3, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':         Load    Time
# 0      -0.66   0.000
# 1       0.58   0.195
# 2       0.58   0.200
# 3       0.58   0.249
# 4      -0.66   0.299
# ...      ...     ...
# 11745   0.00  12.349
# 11746   0.00  12.399
# 11747   0.00  12.449
# 11748   0.00  12.499
# 11749   0.00  12.549
#
# [11750 rows x 2 columns]}, '17_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '17', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 6, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':       Load   Time
# 0     0.48  0.000
# 1     0.48  0.050
# 2     0.56  0.248
# 3     0.56  0.299
# 4     0.50  0.350
# ...    ...    ...
# 6904  0.02  7.249
# 6905  0.00  7.299
# 6906  0.00  7.349
# 6907  0.00  7.399
# 6908  0.00  7.450
#
# [6909 rows x 2 columns]}, '28_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '28', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 10, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -0.40  0.000
# 1     -0.34  0.200
# 2     -0.34  0.250
# 3     -0.40  0.300
# 4     -0.34  0.350
# ...     ...    ...
# 5447   0.00  5.701
# 5448   0.02  5.750
# 5449   0.02  5.800
# 5450   0.02  5.851
# 5451   0.02  5.900
#
# [5452 rows x 2 columns]}, '12_emma_13112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '12', 'user': 'emma', 'date': datetime.datetime(2022, 11, 13, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -2.54  0.000
# 1     -2.54  0.050
# 2     -1.88  0.250
# 3     -1.88  0.301
# 4     -2.52  0.350
# ...     ...    ...
# 7891   0.00  8.300
# 7892   0.00  8.350
# 7893   0.00  8.400
# 7894   0.00  8.450
# 7895   0.00  8.500
#
# [7896 rows x 2 columns]}, '3_kathy_03112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '3', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 3, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load    Time
# 0     -1.20   0.000
# 1     -0.36   0.210
# 2     -0.36   0.248
# 3     -0.36   0.298
# 4     -1.12   0.348
# ...     ...     ...
# 9724   0.10  10.248
# 9725   0.08  10.299
# 9726   0.10  10.348
# 9727   0.08  10.398
# 9728   0.08  10.448
#
# [9729 rows x 2 columns]}, '11_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '11', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 6, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -1.40  0.000
# 1     -0.32  0.172
# 2     -0.32  0.199
# 3     -0.32  0.250
# 4     -1.38  0.299
# ...     ...    ...
# 8220   0.52  8.599
# 8221   0.50  8.649
# 8222   0.50  8.699
# 8223   0.52  8.749
# 8224   0.50  8.799
#
# [8225 rows x 2 columns]}, '3_emma_03112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '3', 'user': 'emma', 'date': datetime.datetime(2022, 11, 3, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load    Time
# 0     -2.10   0.000
# 1     -0.34   0.198
# 2     -0.34   0.250
# 3     -2.08   0.299
# 4     -2.00   0.349
# ...     ...     ...
# 9630   0.00  10.149
# 9631   0.00  10.199
# 9632   0.00  10.250
# 9633   0.00  10.299
# 9634   0.00  10.350
#
# [9635 rows x 2 columns]}, '25_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '25', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 10, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -3.68  0.000
# 1     -3.68  0.044
# 2     -3.68  0.094
# 3     -3.20  0.276
# 4     -3.20  0.294
# ...     ...    ...
# 6857   0.00  7.145
# 6858   0.02  7.195
# 6859   0.00  7.244
# 6860   0.00  7.294
# 6861   0.00  7.344
#
# [6862 rows x 2 columns]}, '6_emma_10112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '6', 'user': 'emma', 'date': datetime.datetime(2022, 11, 10, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':         Load    Time
# 0      -1.86   0.000
# 1      -1.86   0.050
# 2      -0.46   0.229
# 3      -0.46   0.252
# 4      -0.46   0.300
# ...      ...     ...
# 13484   0.02  14.200
# 13485   0.02  14.250
# 13486   0.02  14.300
# 13487   0.02  14.350
# 13488   0.02  14.401
#
# [13489 rows x 2 columns]}, '7_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '7', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 6, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':         Load   Time
# 0     -11.28  0.000
# 1     -12.18  0.196
# 2     -12.18  0.200
# 3     -12.18  0.250
# 4     -11.22  0.300
# ...      ...    ...
# 7609    0.00  7.951
# 7610    0.00  8.000
# 7611    0.00  8.051
# 7612    0.00  8.101
# 7613    0.00  8.150
#
# [7614 rows x 2 columns]}, '4_kathy_03112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '4', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 3, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -1.70  0.000
# 1     -0.70  0.233
# 2     -0.70  0.246
# 3     -0.70  0.296
# 4     -1.68  0.347
# ...     ...    ...
# 8925   0.00  9.396
# 8926   0.00  9.446
# 8927   0.00  9.496
# 8928   0.00  9.546
# 8929   0.00  9.596
#
# [8930 rows x 2 columns]}, '14_emma_13112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '14', 'user': 'emma', 'date': datetime.datetime(2022, 11, 13, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':         Load    Time
# 0      -0.54   0.000
# 1      -0.54   0.049
# 2      -0.54   0.099
# 3       0.14   0.267
# 4       0.14   0.299
# ...      ...     ...
# 30169   0.00  31.949
# 30170   0.00  31.999
# 30171   0.00  32.049
# 30172   0.00  32.099
# 30173   0.00  32.149
#
# [30174 rows x 2 columns]}, '5_emma_03112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '5', 'user': 'emma', 'date': datetime.datetime(2022, 11, 3, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -3.08  0.000
# 1      0.54  1.100
# 2      0.60  1.150
# 3      0.74  1.200
# 4      0.82  1.250
# ...     ...    ...
# 7468   0.00  8.750
# 7469   0.00  8.800
# 7470   0.00  8.850
# 7471   0.00  8.901
# 7472   0.00  8.950
#
# [7473 rows x 2 columns]}, '22_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '22', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 10, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -1.34  0.000
# 1      1.18  1.100
# 2      1.24  1.150
# 3      1.32  1.200
# 4      1.40  1.250
# ...     ...    ...
# 4554   0.26  5.650
# 4555   0.28  5.700
# 4556   0.28  5.751
# 4557   0.28  5.801
# 4558   0.28  5.851
#
# [4559 rows x 2 columns]}, '30_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '30', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 10, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':       Load   Time
# 0     0.56  0.000
# 1     2.52  1.099
# 2     2.58  1.150
# 3     2.58  1.199
# 4     2.70  1.249
# ...    ...    ...
# 6904  0.02  8.150
# 6905  0.02  8.199
# 6906  0.02  8.249
# 6907  0.02  8.299
# 6908  0.02  8.350
#
# [6909 rows x 2 columns]}, '16_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '16', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 6, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load    Time
# 0     -0.36   0.000
# 1     -0.36   0.050
# 2     -0.34   0.100
# 3      0.06   0.262
# 4      0.06   0.301
# ...     ...     ...
# 9348   0.02   9.801
# 9349   0.00   9.851
# 9350   0.00   9.900
# 9351   0.00   9.950
# 9352   0.02  10.000
#
# [9353 rows x 2 columns]}, '29_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '29', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 10, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -0.30  0.000
# 1     -0.32  0.050
# 2     -0.32  0.100
# 3     -0.14  0.276
# 4     -0.14  0.300
# ...     ...    ...
# 6575   0.00  6.850
# 6576   0.02  6.900
# 6577   0.02  6.951
# 6578   0.02  7.001
# 6579   0.02  7.050
#
# [6580 rows x 2 columns]}, '2_kathy_03112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '2', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 3, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -0.92  0.000
# 1     -0.92  0.050
# 2      0.42  0.218
# 3      0.42  0.250
# 4      0.42  0.299
# ...     ...    ...
# 7045   0.00  7.349
# 7046   0.00  7.400
# 7047   0.00  7.449
# 7048   0.00  7.500
# 7049   0.00  7.550
#
# [7050 rows x 2 columns]}, '10_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '10', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 6, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':         Load    Time
# 0      -0.78   0.000
# 1      -0.08   0.218
# 2      -0.08   0.250
# 3      -0.08   0.299
# 4      -0.70   0.349
# ...      ...     ...
# 10899   0.00  11.500
# 10900   0.00  11.549
# 10901   0.00  11.599
# 10902   0.00  11.649
# 10903   0.00  11.699
#
# [10904 rows x 2 columns]}, '6_kathy_06112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '6', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 6, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':         Load    Time
# 0      -0.50   0.000
# 1       1.04   0.247
# 2       1.04   0.300
# 3      -0.48   0.350
# 4      -0.42   0.400
# ...      ...     ...
# 13907   0.00  14.750
# 13908   0.00  14.800
# 13909   0.00  14.850
# 13910   0.00  14.900
# 13911   0.00  14.951
#
# [13912 rows x 2 columns]}, '24_kathy_10112022_AnchorFailureBlackAcrylic_SuturePad.log': {'trail': '24', 'user': 'kathy', 'date': datetime.datetime(2022, 11, 10, 0, 0), 'setup_env': 'AnchorFailureBlackAcrylic', 'material': 'SuturePad', 'data':        Load   Time
# 0     -0.82  0.000
# 1     -0.70  0.190
# 2     -0.70  0.200
# 3     -0.80  0.251
# 4     -0.80  0.300
# ...     ...    ...
# 6669   0.00  6.951
# 6670   0.00  7.000
# 6671   0.00  7.051
# 6672   0.00  7.100
# 6673   0.00  7.150
#
# [6674 rows x 2 columns]}}

# %% [markdown]
# Data Cleaning

# %%
# Cleaning and data engineering functions


'''
Purpose: 
Parameters: 
Return: 
'''

# NONE FOR NOW YEEEEE
# Out:
# '\nPurpose: \nParameters: \nReturn: \n'

# %%
# Apply each cleaning function to each dataframe.

# NONE FOR NOW YEEEEE

# %% [markdown]
# Data Analysis
#
#
# {'1_kathy_11062022_AnchorFailureBlackAcryllic_SuturePad.log':
#     {'trail': '1',
#      'user': 'kathy',
#      'date': datetime.datetime(2022, 6, 11, 0, 0),
#      'setup_env': 'AnchorFailureBlackAcryllic',
#      'material': 'SuturePad',
#      'data':       Load    Time
#             0    -0.50   0.000
#             1     1.04   0.247
#             2     1.04   0.300
#             3    -0.48   0.350
#             4    -0.42   0.400
#             ..     ...     ...
#             883   0.00  14.750
#             884   0.00  14.800
#             885   0.00  14.850
#             886   0.00  14.900
#             887   0.00  14.951

# %%
# Analysis functions

'''
Purpose: Scatter plot of breakaway data and show somes stats
Parameters:
- all_data (main data structure)
- measurements (list): ["Load (N), Time (sec)"]
Return: None
'''


def plot_breakaway(all_data):
    
    setup_envs = []
    materials = []
    users = []
    for filename in all_data:
        data = all_data[filename]
        if data["setup_env"] not in setup_envs:
            setup_envs.append(data["setup_env"])
        if data["material"] not in materials:
            materials.append(data["material"])
        if data["user"] not in users:
            users.append(data["user"])
        
    user_col = []
    max_force_col = []
    for user in users:
        # Get specific file to analyze
        for filename in all_data:
            data = all_data[filename]
            if (data["user"] == user):
                df = data['data']
                df['Load'] = df['Load'].astype(float)
                y = df['Load'].values
                user_col.append(user)
                max_force_col.append(max(y))

    d = {'user': user_col, 'max_force': max_force_col}
    my_df = pd.DataFrame(data=d)
    #display(my_df)
    
    sns.set_style("whitegrid")
    sns.set(rc={'figure.figsize':(15,10)})
    p = sns.stripplot(x="user", y="max_force", data=my_df, size=7, color=".7")
    plt.xticks(rotation=45, ha="right")
    #p.set(yscale='log')
    # plot the mean line
    ax = sns.boxplot(showmeans=True,
                meanline=True,
                meanprops={'color': 'k', 'ls': '-', 'lw': 2},
                medianprops={'visible': False},
                whiskerprops={'visible': False},
                zorder=10,
                x="user",
                y="max_force",
                data=my_df,
                showfliers=False,
                showbox=True,
                showcaps=True,
                ax=p)
    ax.set(ylim=(0, 20))
    plt.show()

# %%
# Apply analysis functions
plot_breakaway(all_data)
